# %% [markdown]
# # Bayesian Network
# Knowledge Representation => DAG + CPD

# %%
pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\yeo\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: networkx in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (3.3)
# Requirement already satisfied: numpy in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (1.26.4)
# Requirement already satisfied: scipy in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (1.5.1)
# Requirement already satisfied: pandas in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (2.2.2)
# Requirement already satisfied: torch in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (2.9.1)
# Requirement already satisfied: statsmodels in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (0.14.2)
# Requirement already satisfied: tqdm in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (4.66.5)
# Requirement already satisfied: joblib in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt-einsum in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\yeo\anaconda3\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yeo\anaconda3\lib\site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yeo\anaconda3\lib\site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yeo\anaconda3\lib\site-packages (from pandas->pgmpy) (2023.3)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\yeo\anaconda3\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\yeo\anaconda3\lib\site-packages (from torch->pgmpy) (75.1.0)
# Requirement already satisfied: colorama in c:\users\yeo\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yeo\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\yeo\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\yeo\anaconda3\lib\site-packages (from statsmodels->pgmpy) (24.1)
# Requirement already satisfied: six in c:\users\yeo\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->pgmpy) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yeo\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yeo\anaconda3\lib\site-packages (from jinja2->torch->pgmpy) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Refer the lecture 9 in details

# %%
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# Define the Bayesian Network structure
model = DiscreteBayesianNetwork([
    ('Burglary', 'Alarm'),
    ('Earthquake', 'Alarm'),
    ('Alarm', 'John Call'),
    ('Alarm', 'Mary Call')
])

# Define CPDs
cpd_burglary = TabularCPD(variable='Burglary', variable_card=2, values=[[0.999], [0.001]])
cpd_earthquake = TabularCPD(variable='Earthquake', variable_card=2, values=[[0.998], [0.002]])

# Alarm given Burglary and Earthquake
cpd_alarm = TabularCPD(
    variable='Alarm', variable_card=2,
    values=[
        [0.999, 0.71, 0.06, 0.05],  # Alarm Off
        [0.001, 0.29, 0.94, 0.95]   # Alarm On
    ],
    evidence=['Burglary', 'Earthquake'],
    evidence_card=[2, 2]
)

# John Call given Alarm
cpd_john_call = TabularCPD(
    variable='John Call', variable_card=2,
    values=[
        [0.95, 0.1],  # Call No
        [0.05, 0.9]   # Call Yes
    ],
    evidence=['Alarm'],
    evidence_card=[2]
)

# Mary Call given Alarm
cpd_mary_call = TabularCPD(
    variable='Mary Call', variable_card=2,
    values=[
        [0.99, 0.3],  # Call No
        [0.01, 0.7]   # Call Yes
    ],
    evidence=['Alarm'],
    evidence_card=[2]
)


# Add CPDs to the model
model.add_cpds(cpd_burglary, cpd_earthquake, cpd_alarm, cpd_john_call,cpd_mary_call)

# Validate the model
print("Model is valid:", model.check_model())

# Print CPDs
print("\nCPD for Burglary:\n", cpd_burglary)
print("\nCPD for Earthquake:\n", cpd_earthquake)
print("\nCPD for Alarm:\n", cpd_alarm)
print("\nCPD for John Call:\n", cpd_john_call)
print("\nCPD for Mary Call:\n", cpd_mary_call)
# Out:
# Model is valid: True
#
# CPD for Burglary:
#  +-------------+-------+
# | Burglary(0) | 0.999 |
# +-------------+-------+
# | Burglary(1) | 0.001 |
# +-------------+-------+
#
# CPD for Earthquake:
#  +---------------+-------+
# | Earthquake(0) | 0.998 |
# +---------------+-------+
# | Earthquake(1) | 0.002 |
# +---------------+-------+
#
# CPD for Alarm:
#  +------------+---------------+---------------+---------------+---------------+
# | Burglary   | Burglary(0)   | Burglary(0)   | Burglary(1)   | Burglary(1)   |
# +------------+---------------+---------------+---------------+---------------+
# | Earthquake | Earthquake(0) | Earthquake(1) | Earthquake(0) | Earthquake(1) |
# +------------+---------------+---------------+---------------+---------------+
# | Alarm(0)   | 0.999         | 0.71          | 0.06          | 0.05          |
# +------------+---------------+---------------+---------------+---------------+
# | Alarm(1)   | 0.001         | 0.29          | 0.94          | 0.95          |
# +------------+---------------+---------------+---------------+---------------+
#
# CPD for John Call:
#  +--------------+----------+----------+
# | Alarm        | Alarm(0) | Alarm(1) |
# +--------------+----------+----------+
# | John Call(0) | 0.95     | 0.1      |
# +--------------+----------+----------+
# | John Call(1) | 0.05     | 0.9      |
# +--------------+----------+----------+
#
# CPD for Mary Call:
#  +--------------+----------+----------+
# | Alarm        | Alarm(0) | Alarm(1) |
# +--------------+----------+----------+
# | Mary Call(0) | 0.99     | 0.3      |
# +--------------+----------+----------+
# | Mary Call(1) | 0.01     | 0.7      |
# +--------------+----------+----------+

# %% [markdown]
# ## Visualize DAG

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a NetworkX graph from the Bayesian Network
graph = nx.DiGraph()  
graph.add_edges_from(model.edges())  

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(graph) 
nx.draw(
    graph, pos,
    with_labels=True,
    node_size=3000,
    node_color='skyblue',
    font_size=12,
    font_color='black',
    arrowsize=20,
    edge_color='gray'
)
plt.title("Bayesian Network: Burglary, Earthquake, Alarm, John Call and Mary Call", fontsize=16)
plt.show()

# %% [markdown]
# ## Probabilistic Inference

# %%
from pgmpy.inference import VariableElimination

inference = VariableElimination(model)
p_john_call = inference.query(variables=["John Call"])

p_mary_call = inference.query(variables=["Mary Call"])

p_john_call_a = inference.query(variables=["John Call"],evidence={"Alarm":1})

p_a = inference.query(variables=["Alarm"])

p_a_earthquake_burglary = inference.query(variables=["Alarm"],evidence={"Earthquake":1,"Burglary":1})

joint_p_a_earthquake_burglary_john_mary = (inference.query(variables=["Alarm"],evidence={"Earthquake":0,"Burglary":0}).values[1] * 
                                           inference.query(variables=["Earthquake"]).values[0] *
                                           inference.query(variables=["Burglary"]).values[0] * 
                                           inference.query(variables=["John Call"],evidence={"Alarm":1}).values[1] *
                                           inference.query(variables=["Mary Call"],evidence={"Alarm":1}).values[1])
joint_p_a_earthquake_burglary_john_mary2 = (inference.query(variables=["Alarm","Earthquake","Burglary","John Call","Mary Call"],
                                            joint=True).values[1,0,0,1,1])  
                                           
p_burglary_john_mary_call = inference.query(variables=["Burglary"],evidence={"John Call":1,"Mary Call":1})

joint_p_eaj = inference.query(variables=["Earthquake","Alarm","John Call"], joint=True).values[1,1,1]

joint_p_jm = inference.query(variables=["John Call","Mary Call"], joint=True).values[1,1]

                                        
print("\nP(J):\n", p_john_call)
print("\nP(M):\n", p_mary_call)
print("\nP(J|A):\n", p_john_call_a)
print("\nP(A):\n", p_a)
print("\nP(A|E,B):\n", p_a_earthquake_burglary)
print("\nP(+a,-e,-b,+j,+m):", f"{joint_p_a_earthquake_burglary_john_mary:.6f}")
print("\nP(+a,-e,-b,+j,+m):", f"{joint_p_a_earthquake_burglary_john_mary2:.6f}")
#print("\n")
print("\nP(B|J,M):\n",p_burglary_john_mary_call)

print("\nP(+e,+a,+j):",joint_p_eaj)
print("\nP(+j,+m):",joint_p_jm)
# Out:
# P(J):
#  +--------------+------------------+
# | John Call    |   phi(John Call) |
# +==============+==================+
# | John Call(0) |           0.9479 |
# +--------------+------------------+
# | John Call(1) |           0.0521 |
# +--------------+------------------+
#
# P(M):
#  +--------------+------------------+
# | Mary Call    |   phi(Mary Call) |
# +==============+==================+
# | Mary Call(0) |           0.9883 |
# +--------------+------------------+
# | Mary Call(1) |           0.0117 |
# +--------------+------------------+
#
# P(J|A):
#  +--------------+------------------+
# | John Call    |   phi(John Call) |
# +==============+==================+
# | John Call(0) |           0.1000 |
# +--------------+------------------+
# | John Call(1) |           0.9000 |
# +--------------+------------------+
#
# P(A):
#  +----------+--------------+
# | Alarm    |   phi(Alarm) |
# +==========+==============+
# | Alarm(0) |       0.9975 |
# +----------+--------------+
# | Alarm(1) |       0.0025 |
# +----------+--------------+
#
# P(A|E,B):
#  +----------+--------------+
# | Alarm    |   phi(Alarm) |
# +==========+==============+
# | Alarm(0) |       0.0500 |
# +----------+--------------+
# | Alarm(1) |       0.9500 |
# +----------+--------------+
#
# P(+a,-e,-b,+j,+m): 0.000628
#
# P(+a,-e,-b,+j,+m): 0.000628
#
# P(B|J,M):
#  +-------------+-----------------+
# | Burglary    |   phi(Burglary) |
# +=============+=================+
# | Burglary(0) |          0.7158 |
# +-------------+-----------------+
# | Burglary(1) |          0.2842 |
# +-------------+-----------------+
#
# P(+e,+a,+j): 0.000523188
#
# P(+j,+m): 0.0020841002390000005

# %%
model.add_cpds(TabularCPD(variable='Burglary', variable_card=2, values=[[0.0], [1.0]]))
p_john_call_burglary = inference.query(variables=["John Call"],evidence={"Burglary":1})
print(p_john_call_burglary)
# Out:
# WARNING:pgmpy:Replacing existing CPD for Burglary
# +--------------+------------------+
# | John Call    |   phi(John Call) |
# +==============+==================+
# | John Call(0) |           0.1510 |
# +--------------+------------------+
# | John Call(1) |           0.8490 |
# +--------------+------------------+

# %% [markdown]
# ## Causal Inference

# %% [markdown]
# ## Exercises
# 1. Demonstrate the calculation of the probability that John call. <br>
# 2. Demonstrate the calculation of the probability that Mary call. <br>
# 3. Demonstrate the calculation of the probability that the alarm has occured but neither a burglary nor an earthquake has occured and both John and Mary call?
# 4. Demonstrate the calculation of the probability that there is a burglary given that John and Mary call?

# %% [markdown]
# # Unsupervised Learning Using Bayesian Network with Bayesian Information Criterion Score

# %%
from sklearn.datasets import load_iris
import pandas as pd
from pgmpy.estimators import HillClimbSearch
from pgmpy.estimators.StructureScore import BIC
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator
from scipy.stats import chi2_contingency

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# Discretize the data (necessary for Bayesian networks)
# Discretize using pandas qcut (quantile-based discretization)
discretized_data = data.apply(lambda x: pd.qcut(x, q=3, labels=False))

# Perform structure learning using HillClimbSearch with BIC score
hc = HillClimbSearch(discretized_data)
best_model = hc.estimate(scoring_method=BIC(discretized_data))

# Display the learned structure
print("Learned Structure:", best_model.edges())

# Fit parameters to the learned structure
model = DiscreteBayesianNetwork(best_model.edges())
model.fit(discretized_data, estimator=MaximumLikelihoodEstimator)

# Display the learned CPDs
print("CPDs:")
for cpd in model.get_cpds():
    print(cpd)
# Out:
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'sepal length (cm)': 'N', 'sepal width (cm)': 'N', 'petal length (cm)': 'N', 'petal width (cm)': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'sepal length (cm)': 'N', 'sepal width (cm)': 'N', 'petal length (cm)': 'N', 'petal width (cm)': 'N'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'sepal length (cm)': 'N', 'sepal width (cm)': 'N', 'petal length (cm)': 'N', 'petal width (cm)': 'N'}
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'sepal length (cm)': 'N', 'sepal width (cm)': 'N', 'petal length (cm)': 'N', 'petal width (cm)': 'N'}
# Learned Structure: [('petal length (cm)', 'sepal length (cm)'), ('petal width (cm)', 'petal length (cm)'), ('petal width (cm)', 'sepal width (cm)')]
# CPDs:
# +----------------------+---------------------+---------------------+---------------------+
# | petal width (cm)     | petal width (cm)(0) | petal width (cm)(1) | petal width (cm)(2) |
# +----------------------+---------------------+---------------------+---------------------+
# | petal length (cm)(0) | 1.0                 | 0.0                 | 0.0                 |
# +----------------------+---------------------+---------------------+---------------------+
# | petal length (cm)(1) | 0.0                 | 0.9038461538461539  | 0.14583333333333334 |
# +----------------------+---------------------+---------------------+---------------------+
# | petal length (cm)(2) | 0.0                 | 0.09615384615384616 | 0.8541666666666666  |
# +----------------------+---------------------+---------------------+---------------------+
# +----------------------+----------------------+----------------------+----------------------+
# | petal length (cm)    | petal length (cm)(0) | petal length (cm)(1) | petal length (cm)(2) |
# +----------------------+----------------------+----------------------+----------------------+
# | sepal length (cm)(0) | 0.9                  | 0.12962962962962962  | 0.0                  |
# +----------------------+----------------------+----------------------+----------------------+
# | sepal length (cm)(1) | 0.1                  | 0.6851851851851852   | 0.30434782608695654  |
# +----------------------+----------------------+----------------------+----------------------+
# | sepal length (cm)(2) | 0.0                  | 0.18518518518518517  | 0.6956521739130435   |
# +----------------------+----------------------+----------------------+----------------------+
# +---------------------+----------+
# | petal width (cm)(0) | 0.333333 |
# +---------------------+----------+
# | petal width (cm)(1) | 0.346667 |
# +---------------------+----------+
# | petal width (cm)(2) | 0.32     |
# +---------------------+----------+
# +---------------------+---------------------+----------------------+---------------------+
# | petal width (cm)    | petal width (cm)(0) | petal width (cm)(1)  | petal width (cm)(2) |
# +---------------------+---------------------+----------------------+---------------------+
# | sepal width (cm)(0) | 0.04                | 0.7115384615384616   | 0.375               |
# +---------------------+---------------------+----------------------+---------------------+
# | sepal width (cm)(1) | 0.3                 | 0.25                 | 0.4583333333333333  |
# +---------------------+---------------------+----------------------+---------------------+
# | sepal width (cm)(2) | 0.66                | 0.038461538461538464 | 0.16666666666666666 |
# +---------------------+---------------------+----------------------+---------------------+

# %% [markdown]
# ## Visualize DAG

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a NetworkX graph from the Bayesian Network
graph = nx.DiGraph()  
graph.add_edges_from(model.edges()) 

# Plot the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(graph) 
nx.draw(
    graph, pos,
    with_labels=True,
    node_size=3000,
    node_color='skyblue',
    font_size=12,
    font_color='black',
    arrowsize=20,
    edge_color='gray'
)
plt.title("Learned Bayesian Network", fontsize=16)
plt.show()
