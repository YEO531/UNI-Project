# %% [markdown]
# **Decision Tree**
#
# Step 1 <br>
# Import necessary libraries, this include os, pandas, numpy, matplotli, seaborn, simple imputer, train test split,

# %%
#Step 1: libraries

# %%
#Step 2: Get the path, read in data through pandas and save in variable 'train'

# %%
#first run, ignore this categorical feature
#second run, include this and observe the improvement of classification accuracy
#add categorical feature
# Include categorical features like Sex and Embarked
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
train = pd.get_dummies(train, columns=['Embarked'], drop_first=True)

# %%
# Step 3: Select numerical features and drop 'Survived' and 'PassengerID'
#Then, assign the selected features to 'X', whereas 'Survived' to 'y'
#[Hints: refer lab7b]

# %%
#Step 4:
# Impute missing values

#Step 5:
# Split data into X_train, X_test, y_train, y_test.
#Set the test_size to 0.3 and random_state = 101

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# Initialize and train Decision Tree
dt_model = DecisionTreeClassifier(
    max_depth=4,               # Limit tree depth to prevent overfitting
    min_samples_split=20,      # Minimum samples required to split a node
    min_samples_leaf=10,       # Minimum samples required at a leaf node
    random_state=42
)
dt_model.fit(X_train, y_train)

# Make predictions
y_pred = dt_model.predict(X_test)

# %%
# Evaluate model
accuracy = accuracy_score(y_test, y_pred)
print(f"Decision Tree Accuracy: {accuracy:.2%}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Decision Tree Accuracy: 79.10%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.95      0.84       154
#            1       0.90      0.57      0.70       114
#
#     accuracy                           0.79       268
#    macro avg       0.83      0.76      0.77       268
# weighted avg       0.81      0.79      0.78       268

# %%
# Step 6: Visualize the results through Confusion Matrix

# %%
# Visualize the decision tree
plt.figure(figsize=(20, 10))
plot_tree(
    dt_model,
    filled=True,
    feature_names=X.columns,
    class_names=['Died', 'Survived'],
    proportion=True,
    rounded=True,
    fontsize=10
)
plt.title("Decision Tree for Titanic Survival Prediction")
plt.show()

# %% [markdown]
# Now, observe the results and record the results.
# <br>
# Next, include categorical features Sex and Embarked. The code is given as below. Make sure you put it in the correct section and re-run the decision tree.<br>
# What can you observe from this result? Is there any improvement?

# %%
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
train = pd.get_dummies(train, columns=['Embarked'], drop_first=True)
