# %% [markdown]
# ##SVM (Titanic Dataset)
# Assume that you need to apply SVM. The goal is to predict the survived result from Titanic dataset.
# Step 1, you need to import pandas, numpy, matplot, seaborn, and a lot of modules from sklearn (including SVC from svm, accuracy score and confusion matrix from metrics, train_test_split from model_selection, and StandardScaler from preprocessing).

# %%
#Step 1:
#import all the necessary libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#Step 2: Get the path, read in data through pandas and save in variable 'train'
"C:\Users\YEO\OneDrive\Desktop\Degree\Year 2\SEM 3 LONG SEM (2025)\TML6223-MACHINE LEARNING (ML1,1E)\LAB\Lab7\Lab7\titanic_test.csv"

# %%
#perform Feature engineering
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
train['FamilySize'] = train['SibSp'] + train['Parch'] + 1
train['Age'].fillna(train['Age'].median(), inplace=True)
train['Fare'].fillna(train['Fare'].median(), inplace=True)

# %%
#Step 4: Select featuers and target
#features save in X, the target variable 'Survived' save in Y

# %%
#Step 5: Split data with test_size = 0.3, random_state = 42

# %%
#Step 6:
#standardized the features by calling StandardScaler()
#Then, save the scaled data into your train test variable (not including the target)

# %%
#Step 7a:
#train SVM with rbf kernel, C=1.0, gamme='scale', random_state=42
#and assign to variable 'svm'

# %%
#Step 7b:#train SVM with linear kernel, C=1.0
#and assign to variable 'svm_linear'

# %%
# Predictions and evaluation
y_pred1 = svm.predict(X_test_scaled)
y_pred2 = svm_linear.predict(X_test_scaled)
accuracy1 = accuracy_score(y_test, y_pred1)
accuracy2 = accuracy_score(y_test, y_pred2)
print(f"SVM Accuracy with RBF Kernel: {accuracy1:.2%}")
print(f"SVM Accuracy with Linear Kernel: {accuracy2:.2%}")

# %%
#Step 8: Display confusion matrix of both SVM

# %%
# Decision boundary visualization (using PCA for 2D projection)
def plot_decision_boundary():
    # Reduce to 2 dimensions using PCA
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_train_scaled)

    # Create grid for plotting
    x_min, x_max = X_pca[:, 0].min() - 1, X_pca[:, 0].max() + 1
    y_min, y_max = X_pca[:, 1].min() - 1, X_pca[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                         np.arange(y_min, y_max, 0.02))

    # Train SVM on PCA-transformed data
    #svm_pca = SVC(kernel='rbf', C=1.0, gamma='scale')
    svm_pca = SVC(kernel='linear', C=1.0)
    svm_pca.fit(X_pca, y_train)

    # Predict on grid
    Z = svm_pca.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.contourf(xx, yy, Z, alpha=0.4, cmap='coolwarm')
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_train, cmap='coolwarm', edgecolors='k')
    plt.scatter(svm_pca.support_vectors_[:, 0],
                svm_pca.support_vectors_[:, 1],
                s=100, facecolors='none', edgecolors='k', label='Support Vectors')
    plt.title('SVM Decision Boundary with Support Vectors (PCA-reduced)')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend()
    plt.show()

plot_decision_boundary()

# %% [markdown]
# Try this: unscale the data and observe the results
